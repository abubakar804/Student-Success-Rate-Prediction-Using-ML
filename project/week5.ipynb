# %%
plt.figure(figsize=(30,10))
plt.hist(df1['Initial Screening Percentage'], bins=30, density= True)
# Out:
# (array([0.02110051, 0.03165076, 0.03692589, 0.07912691, 0.13187818,
#         0.13715331, 0.31650763, 0.51168734, 0.51696246, 1.01282442,
#         1.44010972, 1.96762244, 1.88849553, 2.5795372 , 2.42128338,
#         2.99627224, 2.71141538, 1.91487117, 1.93069655, 1.19217875,
#         0.75434319, 0.51696246, 0.37980916, 0.25848123, 0.27958174,
#         0.22155534, 0.11077767, 0.03692589, 0.03165076, 0.04220102]),
#  array([-0.12      , -0.08222222, -0.04444444, -0.00666667,  0.03111111,
#          0.06888889,  0.10666667,  0.14444444,  0.18222222,  0.22      ,
#          0.25777778,  0.29555556,  0.33333333,  0.37111111,  0.40888889,
#          0.44666667,  0.48444444,  0.52222222,  0.56      ,  0.59777778,
#          0.63555556,  0.67333333,  0.71111111,  0.74888889,  0.78666667,
#          0.82444444,  0.86222222,  0.9       ,  0.93777778,  0.97555556,
#          1.01333333]),
#  <a list of 30 Patch objects>)

# %%
plt.figure(figsize=(30,10))
df1['Points Scored Screning Test']=df1['Points Scored Screning Test'].values.astype(str)
plt.hist(df1['Points Scored Screning Test'], bins=30, density= True)
# Out:
# (array([0.26598585, 0.01184415, 0.00924972, 0.00812171, 0.01116734,
#         0.00349685, 0.01026493, 0.01161855, 0.01049054, 0.01624341,
#         0.00947532, 0.01308497, 0.00902412, 0.01748423, 0.00902412,
#         0.00958812, 0.01398738, 0.01015213, 0.0077833 , 0.01218256,
#         0.00462486, 0.00552727, 0.00642968, 0.01872504, 0.01128015,
#         0.00868571, 0.01173135, 0.01342337, 0.00270724, 0.01263376]),
#  array([ 0.        ,  1.76666667,  3.53333333,  5.3       ,  7.06666667,
#          8.83333333, 10.6       , 12.36666667, 14.13333333, 15.9       ,
#         17.66666667, 19.43333333, 21.2       , 22.96666667, 24.73333333,
#         26.5       , 28.26666667, 30.03333333, 31.8       , 33.56666667,
#         35.33333333, 37.1       , 38.86666667, 40.63333333, 42.4       ,
#         44.16666667, 45.93333333, 47.7       , 49.46666667, 51.23333333,
#         53.        ]),
#  <a list of 30 Patch objects>)

# %%
plt.hist(df1['Submitted At'])
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 5.017e+03]),
#  array([    0.      ,  4373.162622,  8746.325244, 13119.487866,
#         17492.650488, 21865.81311 , 26238.975732, 30612.138354,
#         34985.300976, 39358.463598, 43731.62622 ]),
#  <a list of 10 Patch objects>)

# %%
df1['CGPA/Final Average GPA']=df1['CGPA/Final Average GPA'].values.astype(str)
plt.hist(df1['CGPA/Final Average GPA'])
# Out:
# (array([4.770e+02, 0.000e+00, 0.000e+00, 2.052e+03, 0.000e+00, 0.000e+00,
#         2.487e+03, 0.000e+00, 0.000e+00, 2.000e+00]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(30,10))
plt.hist(df1['Age'], bins=30, density=True)
# Out:
# (array([0.00822041, 0.02260612, 0.04726734, 0.09135861, 0.13507623,
#         0.13638402, 0.11844859, 0.09117178, 0.07230221, 0.05137754,
#         0.03736548, 0.03400259, 0.02410074, 0.01718812, 0.01475937,
#         0.0190564 , 0.00653896, 0.00336289, 0.00224193, 0.00168145,
#         0.00112096, 0.00093414, 0.00018683, 0.00018683, 0.00018683,
#         0.00018683, 0.        , 0.        , 0.        , 0.00018683]),
#  array([17.        , 18.06666667, 19.13333333, 20.2       , 21.26666667,
#         22.33333333, 23.4       , 24.46666667, 25.53333333, 26.6       ,
#         27.66666667, 28.73333333, 29.8       , 30.86666667, 31.93333333,
#         33.        , 34.06666667, 35.13333333, 36.2       , 37.26666667,
#         38.33333333, 39.4       , 40.46666667, 41.53333333, 42.6       ,
#         43.66666667, 44.73333333, 45.8       , 46.86666667, 47.93333333,
#         49.        ]),
#  <a list of 30 Patch objects>)

# %%
plt.hist(df1['Gender'], bins=3, density=True)
# Out:
# (array([2.77162216, 0.        , 0.22837784]),
#  array([0.        , 0.33333333, 0.66666667, 1.        ]),
#  <a list of 3 Patch objects>)
