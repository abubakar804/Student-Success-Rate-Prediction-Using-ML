# %%
plt.figure(figsize=(20,8))
plt.hist(df1['Agreegate Percentage'])
# Out:
# (array([  56.,  402., 1240., 1162.,  838.,  655.,  340.,  190.,  106.,
#           29.]),
#  array([-0.05666667,  0.043     ,  0.14266667,  0.24233333,  0.342     ,
#          0.44166667,  0.54133333,  0.641     ,  0.74066667,  0.84033333,
#          0.94      ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(20,8))
plt.hist(df1['Agreegate Percentage'], bins = 30, density=True)
# Out:
# (array([0.05998472, 0.09597556, 0.17995417, 0.39589918, 0.71381821,
#         1.30166851, 1.81753713, 2.53735382, 3.08321481, 2.86127133,
#         2.27941951, 1.82953408, 1.64957991, 1.70356616, 1.6735738 ,
#         1.64957991, 1.24768226, 1.03173725, 0.82778919, 0.61184418,
#         0.59984724, 0.44388696, 0.41389459, 0.2819282 , 0.25793431,
#         0.24593737, 0.13196639, 0.09597556, 0.05998472, 0.01799542]),
#  array([-0.05666667, -0.02344444,  0.00977778,  0.043     ,  0.07622222,
#          0.10944444,  0.14266667,  0.17588889,  0.20911111,  0.24233333,
#          0.27555556,  0.30877778,  0.342     ,  0.37522222,  0.40844444,
#          0.44166667,  0.47488889,  0.50811111,  0.54133333,  0.57455556,
#          0.60777778,  0.641     ,  0.67422222,  0.70744444,  0.74066667,
#          0.77388889,  0.80711111,  0.84033333,  0.87355556,  0.90677778,
#          0.94      ]),
#  <BarContainer object of 30 artists>)

# %%
plt.figure(figsize=(30,10))
df1['Screening Test Percentage']=df1['Screening Test Percentage'].values.astype(str)
plt.hist(df1['Screening Test Percentage'], bins=30, density= True)
# Out:
# (array([0.18203697, 0.00781801, 0.00337247, 0.01303002, 0.01387313,
#         0.01440966, 0.01770549, 0.00413895, 0.01103719, 0.00551859,
#         0.00314253, 0.01318331, 0.00551859, 0.00298924, 0.00582518,
#         0.01456296, 0.00751142, 0.00935095, 0.0107306 , 0.00513536,
#         0.0066683 , 0.00551859, 0.00574854, 0.0066683 , 0.00521201,
#         0.00061318, 0.001303  , 0.00045988, 0.00122635, 0.00030659]),
#  array([ 0. ,  2.6,  5.2,  7.8, 10.4, 13. , 15.6, 18.2, 20.8, 23.4, 26. ,
#         28.6, 31.2, 33.8, 36.4, 39. , 41.6, 44.2, 46.8, 49.4, 52. , 54.6,
#         57.2, 59.8, 62.4, 65. , 67.6, 70.2, 72.8, 75.4, 78. ]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(df1['Time'])
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 5.017e+03]),
#  array([0.        , 0.05061458, 0.10122917, 0.15184375, 0.20245833,
#         0.25307292, 0.3036875 , 0.35430208, 0.40491667, 0.45553125,
#         0.50614583]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df1['day'])
# Out:
# (array([   0.,    0.,    0.,    0.,    0., 5018.,    0.,    0.,    0.,
#            0.]),
#  array([0.5, 0.6, 0.7, 0.8, 0.9, 1. , 1.1, 1.2, 1.3, 1.4, 1.5]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df1['hour'])
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 5.017e+03]),
#  array([ 0. ,  1.2,  2.4,  3.6,  4.8,  6. ,  7.2,  8.4,  9.6, 10.8, 12. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df1['min'])
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 5.017e+03]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. , 4.8, 5.6, 6.4, 7.2, 8. ]),
#  <BarContainer object of 10 artists>)
